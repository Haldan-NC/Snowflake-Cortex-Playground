# %% [markdown]
# ### Test Notebook for running Cortex AI with local code
#
# To run this notebook,
#
# 1. Make sure to have Python 3.12.4 installed. That is the latest version with a wheel as seen in this post (https://stackoverflow.com/questions/79135647/pip-install-snowflake-connector-python-fails-building-wheels). Using later versions will demand an installation of Visual Studio C++ 14.0, which i didn't test.
#
# 2. create an environment and install the requirements.txt file
#
# 3. Create Snowflake credentials in windows credential manager (Follow this post: https://medium.com/@aarhar/password-management-in-python-keyring-and-credential-manager-29fa4ccc919e)
#
# 4. Run a query to test you connection (Currently it's not working, but the "basics" are there.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keyring
import os 
import snowflake.connector as sf_connector
import fitz 
import pdfplumber
from langchain.text_splitter import RecursiveCharacterTextSplitter
from collections import defaultdict
from PIL import Image
from io import BytesIO
import layoutparser as lp
import cv2
import numpy as np
import pymupdf4llm
import pathlib

# %% [markdown]
# ## TLDR: This notebook
#
# The idea of this notebook is to create NLP and image oriented functions focused on the application of extracting and strcturing information from a pdf.
#
# It currently contains the following type of functions:
# - A setup/config block of code intended to connect with snowflake databases.
# - A suggestion of the database structure to store the information extracted from the pdf.
# - `extract_manual_metadata()` : Extracts metadata from a PDF file using PyMuPDF.
# - `explore_pdf_fonts_llm_ready()` : Creates a string block of text summarizing the fonts and font sizes used in a PDF file, along with examples. The intended use of this function is to potentially feed this string to a RAG model, to help it understand the structure of the PDF, and perhaps enable the model to label sections of the text, such as "title", "subtitle", "paragraph", "warnings", etc.
# - `extract_text_chunks()` : Extracts all the text data from a PDF file using PyMuPDF, and splits it in a dataframe in string chunks. Could potentially be replaced by CORTEX from Snowflake for more accurate results.
# - `extract_images_from_pdf()` : Extracts all the images from a PDF using a sequence of functions.
#     1. Each PDF are rendered as a list of images using `render_pdf_to_images()`.
#     2. Then each page is processed using `detect_image_regions()`, which runs using classic computer vision techniques:
#         2.1 `cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)` converts the image to grayscale.
#         2.2 `cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)` applies a binary threshold to the grayscale image, meaning that colors above 240 are set to 0 (black) and all values below 240 are set to 255 (white). This creates "black boxes" around the images, and leaves the text areas white.
#         2.3 `cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)` finds the contours of the black boxes, and returns a list of coordinates for each box.
#     3. Using the list of coordinates for the "black regions", which are presumed to be images, the function `crop_regions_from_image()` crops the original page leaving only the image in the region of interest. These images are then saved in a folder corresponding to the file name, and the function returns a list of metadata to the images.
#
#
# ### Notes and considerations:
# - The image extraction process intentionally avoids using modern object segmentation techniques like YOLO or Mask R-CNN, as i found out that these methods have a lot of dependencies which i couldn't make compatible with python 3.12.4. It might be possible, but i believe that the current method of calculating contours is possibly more effective, and orders of magnitude faster than using a deep learning model. This has only been tested on 1 PDF, hence more testing is needed to rely on the methods.
#
#
# ### Import issues
#
# - PyMuPDF and fitz has proved to be slightly frustrating. The best solution i found so far was after installing requirements.txt is to:
#
# ```pythonpip uninstall fitz \n pip install```
#
# ```--upgrade --force-reinstall pymupdf```

# %%
account_identifier = keyring.get_password('NC_Snowflake_Trial_Account_Name', 'account_identifier')
user_name = "JESPEREDSTROM"
password = keyring.get_password('NC_Snowflake_Trial_User_Password', user_name)

print("Account Identifier: ", account_identifier)
print("User Name: ", user_name)
# print("Password: ", password)
# Out:
# Account Identifier:  EDBHJWL-MFB05236
# User Name:  EMILHALDAN5468402

# %%
connection_parameters = {
    "account_identifier": account_identifier,
    "user": user_name,
    "password": password,
    "role": "ACCOUNTADMIN",
    "warehouse": "COMPUTE_WH",
    "database": "CYBERSYN",
    "schema": "PUBLIC"
}

# Connect to Snowflake
conn = sf_connector.connect(
    user=connection_parameters['user'],
    password=connection_parameters['password'],
    account=connection_parameters['account_identifier'],
    warehouse=connection_parameters['warehouse'],
    database=connection_parameters['database'],
    schema=connection_parameters['schema'],
    role=connection_parameters['role']
)

# # Test the connection
cursor = conn.cursor()
cursor.execute("""
    SELECT * 
    FROM company_metadata;
""")

df = cursor.fetch_pandas_all()
df.head(3)
# Out:
#                 CYBERSYN_COMPANY_ID                 COMPANY_NAME  \
# 0  07e85915f5b12be5f0f3fe67276ffc08       CELSIUS HOLDINGS, INC.
# 1  0ac135dfdf2b133215109ccc15754a62  CHURCH & DWIGHT CO INC /DE/
# 2  1443e2413b8a7cb8126ec02fb9096da6            GENERAL MILLS INC
#
#   PERMID_SECURITY_ID PRIMARY_TICKER              SECURITY_NAME  \
# 0         8589948642           CELH   CELSIUS HOLDINGS ORD SHS
# 1         8590943794            CHD  CHURCH AND DWIGHT ORD SHS
# 2         8590933269            GIS      GENERAL MILLS ORD SHS
#
#        ASSET_CLASS PRIMARY_EXCHANGE_CODE    PRIMARY_EXCHANGE_NAME  \
# 0  Ordinary Shares                   NAS    NASDAQ CAPITAL MARKET
# 1  Ordinary Shares                   NYS  NEW YORK STOCK EXCHANGE
# 2  Ordinary Shares                   NYS  NEW YORK STOCK EXCHANGE
#
#   SECURITY_STATUS                                     GLOBAL_TICKERS  \
# 0          Active                                     [\n  "CELH"\n]
# 1          Active  [\n  "0R13",\n  "0R13l",\n  "CHD",\n  "CHD*",\...
# 2          Active  [\n  "0R1X",\n  "0R1Xl",\n  "GIS",\n  "GIS*",\...
#
#                                        EXCHANGE_CODE  \
# 0                                      [\n  "NAS"\n]
# 1  [\n  "BCO",\n  "LSE",\n  "MCX",\n  "MXQ",\n  "...
# 2  [\n  "BCO",\n  "BIV",\n  "LSE",\n  "MCX",\n  "...
#
#                                      PERMID_QUOTE_ID
# 0                              [\n  "25727435733"\n]
# 1  [\n  "21550585218",\n  "21634298419",\n  "2167...
# 2  [\n  "21550585154",\n  "21634298003",\n  "2165...

# %% [markdown]
# ## The intended database structure is as follows:
#
# - **manuals** (Stores metadata about each manual)
#   - `manual_id` (Unique ID for each manual)
#   - `doc_name` ()
#   - `title` (Title of the manual)
#   - `version` (Version or revision number)
#   - `language` (Language code, e.g., 'en', 'de')
#   - `source_path` (Original PDF file path or S3 URL)
#
# - **sections** (Defines logical sections and subsections within each manual)
#   - `section_id` (Unique ID for the section)
#   - `manual_id` (Foreign key referencing `manuals`)
#   - `title` (Title or heading of the section)
#   - `order_num` (Numerical order of the section in the manual)
#   - `parent_section_id` (Optional FK for nested subsections)
#
# - **chunks** (Text chunks derived from section content for LLMs or search) (Perhaps create multiple chunk tables for different chunks sizes)
#   - `chunk_id` (Unique ID for the chunk)
#   - `section_id` (Foreign key referencing `sections`)
#   - `chunk_text` (The text content of the chunk)
#   - `chunk_order` (Order of the chunk within the section)
#   - `embedding` (Vector for semantic search or embeddings)
#
# - **images** (Stores references to images extracted from the manual)
#   - `image_id` (Unique ID for the image)
#   - `manual_id` (Foreign key referencing `manuals`)
#   - `section_id` (Foreign key referencing `sections`)
#   - `image_path` (S3 or web-accessible path to the image)
#   - `caption` (Optional caption or alt text)
#   - `order_num` (Display order within the section)

# %%
manuals_df = pd.DataFrame(columns=['Manual_ID', 'Doc_Name', 'Title', 'Version', 'Language', 'Source_Path'])
sections_df = pd.DataFrame(columns=['Section_ID', 'Manual_ID', 'Doc_Name', 'Order_Num', 'Parent_Section_ID'])
chunks_df = pd.DataFrame(columns=['Chunk_ID', 'Section_ID', 'Manual_ID', 'Order_Num', 'Chunk_Embedding_Vector'])
images_df = pd.DataFrame(columns=['Image_ID', 'Section_ID', 'Manual_ID', 'Order_Num', 'Image_Description' ,'Image_Path'])

# %%
pdf_files_path = "./Washer_Manuals"

for filename in os.listdir(pdf_files_path):
    if filename.endswith(".pdf"):
        file_path = os.path.join(pdf_files_path, filename)
        print(file_path)
        # do something with the file
    else:
        continue
# Out:
# ./Washer_Manuals\k714wm14 service manual.pdf
# ./Washer_Manuals\mmo_87050793_1630397705_64_10689.pdf
# ./Washer_Manuals\technical-manual-w11663204-revb.pdf
# ./Washer_Manuals\WAK20160IN.pdf
# ./Washer_Manuals\WAN28258GB.pdf
# ./Washer_Manuals\WAN28282GC.pdf
# ./Washer_Manuals\Washing machine Top-loader C series.pdf
# ./Washer_Manuals\WAT24168IN.pdf
# ./Washer_Manuals\WAV28KH3GB.pdf
# ./Washer_Manuals\WFL2050.pdf
# ./Washer_Manuals\WGA1340SIN.pdf
# ./Washer_Manuals\WGA1420SIN.pdf
# ./Washer_Manuals\WGE03408GB.pdf
# ./Washer_Manuals\WGG254Z0GB.pdf

# %%
## Extracting metadata from the PDF files

def extract_manual_metadata(file_path):
    doc = fitz.open(file_path)
    metadata = doc.metadata
    return {
        "title": metadata.get("title") or file_path.split("/")[-1],
        "version": metadata.get("modDate") or "v1",
        "language": "en",  # Default, or use NLP detection
        "source_path": file_path
    }

extract_manual_metadata(file_path)
# Out:
# {'title': 'User manual and installation instructions WGG254Z0GB  WGG254ZSGB | Bosch',
#  'version': "D:20240116140125+01'00",
#  'language': 'en',
#  'source_path': './Washer_Manuals\\WGG254Z0GB.pdf'}

# %%
## Exploring the PDF files and their structure

def explore_pdf_fonts_llm_ready(file_path : str, sort_by="size", examples_included:int = 8, verbose:int=0 ) -> str:
    """
    Args:
        file_path (str): A string containing the local path to the PDF file.
        sort_by (str, optional): Defaults to "size".
        verbose (int, optional): Option are (0,1,2) and increases amount of information printed, typically used for confirming documents read. Defaults to 0.

    Returns:
        str: _description_
    """

    doc = fitz.open(file_path)
    font_data = defaultdict(list)

    for p_idx,page in enumerate(doc):
        if verbose > 1:
            # used to show the pages processed to compare with the actual document
            print(f"Processing page {p_idx + 1}/{len(doc)}...")
        blocks = page.get_text("dict")["blocks"]
        for b in blocks:
            for line in b.get("lines", []):
                for span in line.get("spans", []):
                    text = span["text"].strip()
                    if text:
                        font_key = (round(span["size"], 2), span["font"])
                        font_data[font_key].append({
                            "text": text,
                            "size": round(span["size"], 2),
                            "font": span["font"],
                            "page": p_idx + 1,
                            "bbox": span.get("bbox", None),
                            "position": (round(span["origin"][0], 1), round(span["origin"][1], 1))
                        })

    # Sort by font size or font name
    sorted_fonts = sorted(font_data.items(), key=lambda x: -x[0][0] if sort_by == "size" else x[0][1])

    # Build LLM-friendly string
    lines = []
    for (size, font), entries in sorted_fonts:
        line_of_text = f"Font Group: size={size}, font='{font}' (occurrences={len(entries)})"
        lines.append(line_of_text)
        if verbose > 0:
            print("\n"+line_of_text)
        for entry in entries[:examples_included]:  # Show top 5 examples per group
            line_of_text = f"  [Page {entry['page']}] (x={entry['position'][0]}, y={entry['position'][1]}) → {entry['text']}"
            lines.append(line_of_text)
            if verbose > 0:
                print(f"    [Page {entry['page']}] (x={entry['position'][0]}, y={entry['position'][1]}) → {entry['text']}")
        lines.append("")  # blank line between font groups

    return "\n".join(lines)

explore_pdf_fonts_llm_ready(file_path, sort_by="size", examples_included=5, verbose = 1)
# Out:
# Font Group: size=28.0, font='BoschSans-Regular' (occurrences=1)
#     [Page 1] (x=31.5, y=279.2) → Washing machine
#
# Font Group: size=20.0, font='BoschSans-Bold' (occurrences=4)
#     [Page 52] (x=112.0, y=103.0) → Thank you for buying a
#     [Page 52] (x=112.0, y=123.7) → Bosch Home Appliance!
#     [Page 52] (x=112.0, y=327.6) → Looking for help?
#     [Page 52] (x=112.0, y=348.3) → You'll find it here.
#
# Font Group: size=15.37, font='ArialUnicodeMS' (occurrences=1)
#     [Page 19] (x=293.7, y=426.2) → 4
#
# Font Group: size=14.51, font='ArialUnicodeMS' (occurrences=13)
#     [Page 18] (x=38.6, y=341.7) → 1
#     [Page 18] (x=38.6, y=277.9) → 2
#     [Page 18] (x=136.7, y=161.8) → 4
#     [Page 18] (x=260.5, y=162.2) → 6
#     [Page 18] (x=78.1, y=161.8) → 3
#
# Font Group: size=14.45, font='ArialUnicodeMS' (occurrences=9)
#     [Page 19] (x=98.3, y=183.6) → 2
#     [Page 19] (x=185.1, y=107.5) → 3
#     [Page 19] (x=75.8, y=183.6) → 1
#     [Page 19] (x=185.1, y=89.6) → 4
#     [Page 32] (x=354.3, y=164.5) → 1
#
# Font Group: size=14.0, font='NimbusSanL-Bol' (occurrences=31)
#     [Page 2] (x=28.3, y=56.1) → Further information and explanations are
#     [Page 2] (x=28.3, y=71.1) → available online:
#     [Page 2] (x=28.3, y=119.5) → Table of contents
#     [Page 4] (x=51.0, y=60.9) → 1 Safety
#     [Page 10] (x=28.3, y=60.9) → 2 Preventing material
#
# Font Group: size=14.0, font='Code39WideG' (occurrences=1)
#     [Page 52] (x=31.5, y=547.5) → *9001916613*
#
# Font Group: size=13.5, font='ArialUnicodeMS' (occurrences=19)
#     [Page 18] (x=36.1, y=433.1) → 1
#     [Page 18] (x=36.1, y=457.8) → 2
#     [Page 18] (x=36.1, y=475.7) → 3
#     [Page 18] (x=36.1, y=493.7) → 4
#     [Page 18] (x=36.1, y=511.6) → 5
#
# Font Group: size=13.0, font='NimbusSanL-Bol' (occurrences=6)
#     [Page 4] (x=28.3, y=108.1) → 1.1 General information
#     [Page 4] (x=28.3, y=224.7) → 1.2 Intended use
#     [Page 4] (x=28.3, y=367.6) → 1.3 Restriction on user group
#     [Page 5] (x=28.3, y=54.0) → 1.4 Safe installation
#     [Page 7] (x=28.3, y=90.2) → 1.5 Safe use
#
# Font Group: size=12.0, font='NimbusSanL-Lig' (occurrences=164)
#     [Page 4] (x=28.3, y=85.5) → Observe the following safety instructions.
#     [Page 4] (x=35.0, y=159.6) → Read this instruction manual carefully.
#     [Page 4] (x=35.0, y=174.0) → Keep the instruction manual and the product information safe
#     [Page 4] (x=39.7, y=187.8) → for future reference or for the next owner.
#     [Page 4] (x=35.0, y=201.6) → Do not connect the appliance if it has been damaged in transit.
#
# Font Group: size=12.0, font='Wingdings2' (occurrences=7)
#     [Page 4] (x=28.3, y=159.6) → ¡
#     [Page 4] (x=28.3, y=174.0) → ¡
#     [Page 4] (x=28.3, y=201.6) → ¡
#     [Page 4] (x=28.3, y=257.7) → ¡
#     [Page 4] (x=28.3, y=285.3) → ¡
#
# Font Group: size=12.0, font='NimbusSanL-Bol' (occurrences=80)
#     [Page 5] (x=51.0, y=76.8) → WARNING ‒ Risk of electric shock!
#     [Page 5] (x=51.0, y=432.5) → WARNING ‒ Risk of fire!
#     [Page 6] (x=51.0, y=55.3) → WARNING ‒ Risk of injury!
#     [Page 6] (x=51.0, y=258.3) → WARNING ‒ Risk of suffocation!
#     [Page 6] (x=51.0, y=336.9) → CAUTION ‒ Risk of injury!
#
# Font Group: size=12.0, font='ArialUnicodeMS-Bold' (occurrences=57)
#     [Page 5] (x=28.3, y=104.4) → ▶
#     [Page 5] (x=28.3, y=132.0) → ▶
#     [Page 5] (x=28.3, y=159.7) → ▶
#     [Page 5] (x=28.3, y=201.2) → ▶
#     [Page 5] (x=28.3, y=229.4) → ▶
#
# Font Group: size=12.0, font='NimbusSanL-LigIta' (occurrences=1)
#     [Page 7] (x=184.3, y=223.7) → Page 47
#
# Font Group: size=11.0, font='BoschSans-Regular' (occurrences=7)
#     [Page 52] (x=31.5, y=163.9) → Register your new device on MyBosch now and profit directly from:
#     [Page 52] (x=31.5, y=258.8) → Free and easy registration – also on mobile phones:
#     [Page 52] (x=31.5, y=389.4) → Expert advice for your Bosch home appliances, help with problems
#     [Page 52] (x=31.5, y=401.5) → or a repair from Bosch experts.
#     [Page 52] (x=31.5, y=413.7) → Find out everything about the many ways Bosch can support you:
#
# Font Group: size=11.0, font='BoschSans-Bold' (occurrences=2)
#     [Page 52] (x=31.5, y=270.9) → www.bosch-home.com/welcome
#     [Page 52] (x=31.5, y=425.8) → www.bosch-home.com/service
#
# Font Group: size=10.5, font='NimbusSanL-Bol' (occurrences=8)
#     [Page 14] (x=221.1, y=262.7) → Connecting the water inlet hose
#     [Page 15] (x=28.3, y=91.5) → Water outlet connection types
#     [Page 15] (x=221.1, y=52.1) → Connecting the appliance to the
#     [Page 15] (x=221.1, y=63.6) → electricity supply
#     [Page 34] (x=28.3, y=423.3) → Emptying the drain pump
#
# Font Group: size=10.0, font='BoschSans-Bold' (occurrences=3)
#     [Page 1] (x=274.9, y=110.7) → Register
#     [Page 1] (x=257.2, y=154.8) → bosch-home.com/
#     [Page 1] (x=277.5, y=169.1) → welcome
#
# Font Group: size=10.0, font='BoschSans-Light' (occurrences=4)
#     [Page 1] (x=318.8, y=116.5) → your
#     [Page 1] (x=273.5, y=122.2) → new device on
#     [Page 1] (x=263.0, y=132.4) → MyBosch now and
#     [Page 1] (x=264.3, y=144.2) → get free benefits:
#
# Font Group: size=10.0, font='NimbusSanL-Bol' (occurrences=215)
#     [Page 2] (x=28.3, y=136.6) → 1 Safety...........................................  4
#     [Page 2] (x=28.3, y=237.3) → 2 Preventing material damage ....  10
#     [Page 2] (x=28.3, y=256.0) → 3 Environmental protection and
#     [Page 2] (x=36.9, y=266.5) → saving energy............................  11
#     [Page 2] (x=28.3, y=331.5) → 4 Installation and connection......  12
#
# Font Group: size=10.0, font='NimbusSanL-Lig' (occurrences=1842)
#     [Page 2] (x=28.3, y=148.4) → 1.1 General information...................  4
#     [Page 2] (x=28.3, y=160.4) → 1.2 Intended use..............................  4
#     [Page 2] (x=28.3, y=172.3) → 1.3 Restriction on user group..........  4
#     [Page 2] (x=28.3, y=184.2) → 1.4 Safe installation .........................  5
#     [Page 2] (x=28.3, y=196.1) → 1.5 Safe use ....................................  7
#
# Font Group: size=10.0, font='NimbusSanL-LigIta' (occurrences=110)
#     [Page 10] (x=50.3, y=249.3) → "Programmes", Page 24
#     [Page 12] (x=50.3, y=261.1) → "Disposing of packaging",
#     [Page 12] (x=39.7, y=271.8) → Page 11
#     [Page 12] (x=243.0, y=83.0) → "Accessories", Page 28
#     [Page 12] (x=243.0, y=201.0) → "Removing the transit bolts",
#
# Font Group: size=10.0, font='Webdings' (occurrences=19)
#     [Page 11] (x=26.9, y=303.4) → a
#     [Page 11] (x=26.9, y=357.1) → a
#     [Page 11] (x=26.9, y=442.3) → a
#     [Page 11] (x=219.7, y=86.5) → a
#     [Page 11] (x=219.7, y=182.2) → a
#
# Font Group: size=10.0, font='Wingdings2' (occurrences=85)
#     [Page 12] (x=221.1, y=168.5) → ¡
#     [Page 12] (x=221.1, y=179.4) → ¡
#     [Page 12] (x=221.1, y=190.4) → ¡
#     [Page 12] (x=221.1, y=222.2) → ¡
#     [Page 12] (x=221.1, y=233.1) → ¡
#
# Font Group: size=9.0, font='BoschSans-Bold' (occurrences=10)
#     [Page 1] (x=31.5, y=317.3) → WGG254Z0GB
#     [Page 1] (x=31.5, y=328.3) → WGG254ZSGB
#     [Page 1] (x=31.5, y=369.0) → [en]
#     [Page 52] (x=28.6, y=186.0) → • Expert tips & tricks for your appliance
#     [Page 52] (x=28.6, y=198.1) → • Warranty extension options
#
# Font Group: size=9.0, font='BoschSans-Regular' (occurrences=14)
#     [Page 1] (x=68.3, y=369.0) → User manual and installation
#     [Page 1] (x=68.3, y=380.0) → instructions
#     [Page 52] (x=31.5, y=482.1) → Carl-Wery-Straße 34
#     [Page 52] (x=31.5, y=493.4) → 81739 München, GERMANY
#     [Page 52] (x=31.5, y=504.6) → www.bosch-home.com
#
# Font Group: size=9.0, font='NimbusSanL-Bol' (occurrences=48)
#     [Page 2] (x=28.3, y=31.2) → en
#     [Page 3] (x=380.7, y=31.2) → en
#     [Page 4] (x=28.3, y=31.2) → en
#     [Page 5] (x=374.5, y=31.2) → en
#     [Page 6] (x=28.3, y=31.2) → en
#
# Font Group: size=9.0, font='NimbusSanL-Lig' (occurrences=94)
#     [Page 2] (x=28.3, y=570.6) → 2
#     [Page 3] (x=388.5, y=570.6) → 3
#     [Page 4] (x=47.8, y=31.2) → Safety
#     [Page 4] (x=28.3, y=570.6) → 4
#     [Page 5] (x=349.4, y=31.2) → Safety
#
# Font Group: size=9.0, font='ArialUnicodeMS-Bold' (occurrences=40)
#     [Page 10] (x=28.3, y=165.1) → ▶
#     [Page 10] (x=28.3, y=217.6) → ▶
#     [Page 10] (x=28.3, y=312.3) → ▶
#     [Page 10] (x=28.3, y=343.8) → ▶
#     [Page 10] (x=28.3, y=406.8) → ▶
#
# Font Group: size=9.0, font='BoschSans-Light' (occurrences=2)
#     [Page 52] (x=94.6, y=560.6) → (040116)
#     [Page 52] (x=31.5, y=571.8) → en
#
# Font Group: size=8.5, font='ArialUnicodeMS-Bold' (occurrences=107)
#     [Page 11] (x=28.3, y=154.3) → ▶
#     [Page 29] (x=28.3, y=461.1) → ▶
#     [Page 29] (x=221.1, y=151.1) → ▶
#     [Page 30] (x=221.1, y=545.3) → ▶
#     [Page 32] (x=28.3, y=152.1) → ▶
#
# Font Group: size=8.5, font='NimbusSanL-Bol' (occurrences=113)
#     [Page 12] (x=28.3, y=226.6) → 1.
#     [Page 12] (x=28.3, y=283.7) → 2.
#     [Page 12] (x=28.3, y=306.1) → 3.
#     [Page 12] (x=28.3, y=318.0) → 4.
#     [Page 12] (x=28.3, y=340.4) → 5.
#
# Font Group: size=8.0, font='NimbusSanL-Reg' (occurrences=2)
#     [Page 35] (x=232.4, y=126.3) → ‒
#     [Page 36] (x=39.7, y=64.7) → ‒
#
# Font Group: size=5.83, font='NimbusSanL-Lig' (occurrences=25)
#     [Page 20] (x=55.5, y=310.3) → 1
#     [Page 20] (x=43.1, y=334.8) → 1
#     [Page 20] (x=55.5, y=359.5) → 1
#     [Page 20] (x=31.3, y=542.5) → 1
#     [Page 21] (x=78.2, y=506.1) → 1
#
# Font Group: size=5.83, font='NimbusSanL-Bol' (occurrences=6)
#     [Page 48] (x=176.6, y=169.0) → 1
#     [Page 48] (x=214.0, y=179.5) → 1
#     [Page 48] (x=256.8, y=169.0) → 1
#     [Page 48] (x=294.7, y=179.5) → 1
#     [Page 48] (x=339.7, y=148.0) → 1
#
# Font Group: size=0.0, font='NimbusSanL-Bol' (occurrences=40)
#     [Page 10] (x=28.3, y=48.3) → Preventing material damage
#     [Page 10] (x=28.3, y=86.3) → Preventing material damage
#     [Page 11] (x=28.3, y=48.3) → Environmental protection and saving energy
#     [Page 11] (x=28.3, y=86.3) → Environmental protection and saving energy
#     [Page 12] (x=28.3, y=48.3) → Installation and connection
# 'Font Group: size=28.0, font=\'BoschSans-Regular\' (occurrences=1)\n  [Page 1] (x=31.5, y=279.2) → Washing machine\n\nFont Group: size=20.0, font=\'BoschSans-Bold\' (occurrences=4)\n  [Page 52] (x=112.0, y=103.0) → Thank you for buying a\n  [Page 52] (x=112.0, y=123.7) → Bosch Home Appliance!\n  [Page 52] (x=112.0, y=327.6) → Looking for help?\n  [Page 52] (x=112.0, y=348.3) → You\'ll find it here.\n\nFont Group: size=15.37, font=\'ArialUnicodeMS\' (occurrences=1)\n  [Page 19] (x=293.7, y=426.2) → 4\n\nFont Group: size=14.51, font=\'ArialUnicodeMS\' (occurrences=13)\n  [Page 18] (x=38.6, y=341.7) → 1\n  [Page 18] (x=38.6, y=277.9) → 2\n  [Page 18] (x=136.7, y=161.8) → 4\n  [Page 18] (x=260.5, y=162.2) → 6\n  [Page 18] (x=78.1, y=161.8) → 3\n\nFont Group: size=14.45, font=\'ArialUnicodeMS\' (occurrences=9)\n  [Page 19] (x=98.3, y=183.6) → 2\n  [Page 19] (x=185.1, y=107.5) → 3\n  [Page 19] (x=75.8, y=183.6) → 1\n  [Page 19] (x=185.1, y=89.6) → 4\n  [Page 32] (x=354.3, y=164.5) → 1\n\nFont Group: size=14.0, font=\'NimbusSanL-Bol\' (occurrences=31)\n  [Page 2] (x=28.3, y=56.1) → Further information and explanations are\n  [Page 2] (x=28.3, y=71.1) → available online:\n  [Page 2] (x=28.3, y=119.5) → Table of contents\n  [Page 4] (x=51.0, y=60.9) → 1\u2000Safety\n  [Page 10] (x=28.3, y=60.9) → 2\u2000Preventing material\n\nFont Group: size=14.0, font=\'Code39WideG\' (occurrences=1)\n  [Page 52] (x=31.5, y=547.5) → *9001916613*\n\nFont Group: size=13.5, font=\'ArialUnicodeMS\' (occurrences=19)\n  [Page 18] (x=36.1, y=433.1) → 1\n  [Page 18] (x=36.1, y=457.8) → 2\n  [Page 18] (x=36.1, y=475.7) → 3\n  [Page 18] (x=36.1, y=493.7) → 4\n  [Page 18] (x=36.1, y=511.6) → 5\n\nFont Group: size=13.0, font=\'NimbusSanL-Bol\' (occurrences=6)\n  [Page 4] (x=28.3, y=108.1) → 1.1\u2000General information\n  [Page 4] (x=28.3, y=224.7) → 1.2\u2000Intended use\n  [Page 4] (x=28.3, y=367.6) → 1.3\u2000Restriction on user group\n  [Page 5] (x=28.3, y=54.0) → 1.4\u2000Safe installation\n  [Page 7] (x=28.3, y=90.2) → 1.5\u2000Safe use\n\nFont Group: size=12.0, font=\'NimbusSanL-Lig\' (occurrences=164)\n  [Page 4] (x=28.3, y=85.5) → Observe the following safety instructions.\n  [Page 4] (x=35.0, y=159.6) → Read this instruction manual carefully.\n  [Page 4] (x=35.0, y=174.0) → Keep the instruction manual and the product information safe\n  [Page 4] (x=39.7, y=187.8) → for future reference or for the next owner.\n  [Page 4] (x=35.0, y=201.6) → Do not connect the appliance if it has been damaged in transit.\n\nFont Group: size=12.0, font=\'Wingdings2\' (occurrences=7)\n  [Page 4] (x=28.3, y=159.6) → ¡\n  [Page 4] (x=28.3, y=174.0) → ¡\n  [Page 4] (x=28.3, y=201.6) → ¡\n  [Page 4] (x=28.3, y=257.7) → ¡\n  [Page 4] (x=28.3, y=285.3) → ¡\n\nFont Group: size=12.0, font=\'NimbusSanL-Bol\' (occurrences=80)\n  [Page 5] (x=51.0, y=76.8) → WARNING\xa0‒\xa0Risk of electric shock!\n  [Page 5] (x=51.0, y=432.5) → WARNING\xa0‒\xa0Risk of fire!\n  [Page 6] (x=51.0, y=55.3) → WARNING\xa0‒\xa0Risk of injury!\n  [Page 6] (x=51.0, y=258.3) → WARNING\xa0‒\xa0Risk of suffocation!\n  [Page 6] (x=51.0, y=336.9) → CAUTION\xa0‒\xa0Risk of injury!\n\nFont Group: size=12.0, font=\'ArialUnicodeMS-Bold\' (occurrences=57)\n  [Page 5] (x=28.3, y=104.4) → ▶\n  [Page 5] (x=28.3, y=132.0) → ▶\n  [Page 5] (x=28.3, y=159.7) → ▶\n  [Page 5] (x=28.3, y=201.2) → ▶\n  [Page 5] (x=28.3, y=229.4) → ▶\n\nFont Group: size=12.0, font=\'NimbusSanL-LigIta\' (occurrences=1)\n  [Page 7] (x=184.3, y=223.7) → Page\xa047\n\nFont Group: size=11.0, font=\'BoschSans-Regular\' (occurrences=7)\n  [Page 52] (x=31.5, y=163.9) → Register your new device on MyBosch now and profit directly from:\n  [Page 52] (x=31.5, y=258.8) → Free and easy registration – also on mobile phones:\n  [Page 52] (x=31.5, y=389.4) → Expert advice for your Bosch home appliances, help with problems\n  [Page 52] (x=31.5, y=401.5) → or a repair from Bosch experts.\n  [Page 52] (x=31.5, y=413.7) → Find out everything about the many ways Bosch c ...

# %%
## Extracting section headers from the PDF files

def extract_text_chunks(file_path, chunk_size=512, chunk_overlap=200):
    with pdfplumber.open(file_path) as pdf:
        full_text = "\n".join([page.extract_text() or "" for page in pdf.pages])

    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    chunks = splitter.split_text(full_text)
    return [{"chunk_order": i, "chunk_text": c} for i, c in enumerate(chunks)]

extract_text_chunks(file_path, 512, 128)[:5]  # Show first 5 chunks
# Out:
# [{'chunk_order': 0,
#   'chunk_text': 'Register\nyour\nb M o ge s y n c t B e h f o r w - e s h e c d o h e b m v n e e i n o c . e w e c f o o i a t m n s n : d /\nwelcome\nWashing machine\nWGG254Z0GB\nWGG254ZSGB\n[en] User manual and installation\ninstructions\nen\nFurther information and explanations are\navailable online:\nTable of contents\n1Safety........................................... 4 8Buttons...................................... 22\n1.1 General information................... 4\n9Programmes.............................. 24'},
#  {'chunk_order': 1,
#   'chunk_text': '1.1 General information................... 4\n9Programmes.............................. 24\n1.2 Intended use.............................. 4\n1.3 Restriction on user group.......... 4 10 Accessories............................. 28\n1.4 Safe installation......................... 5\n1.5 Safe use.................................... 7 11 Laundry.................................... 28\n11.1 Preparing the laundry............ 28\n1.6 Safe cleaning and mainten-\nance........................................... 9'},
#  {'chunk_order': 2,
#   'chunk_text': '11.1 Preparing the laundry............ 28\n1.6 Safe cleaning and mainten-\nance........................................... 9\n12 Detergents and care\nproducts.................................. 29\n2Preventing material damage.... 10\n13 Basic operation....................... 29\n3Environmental protection and\nsaving energy............................ 11 13.1 Switching on the appliance... 29\n3.1 Disposing of packaging.......... 11 13.2 Setting a programme............ 29'},
#  {'chunk_order': 3,
#   'chunk_text': '3.1 Disposing of packaging.......... 11 13.2 Setting a programme............ 29\n3.2 Save energy and conserve 13.3 Adjusting the programme\nresources................................. 11 settings.................................. 29\n3.3 Energy saving mode............... 11 13.4 Loading laundry..................... 29\n13.5 Inserting the measuring aid... 29\n4Installation and connection...... 12 13.6 Using the measuring aid....... 30\n4.1 Unpacking the appliance........ 12\n13.7 Adding detergent and care'},
#  {'chunk_order': 4,
#   'chunk_text': '4.1 Unpacking the appliance........ 12\n13.7 Adding detergent and care\n4.2 Contents of package............... 12 product.................................. 30\n4.3 Requirements for the install- 13.8 Starting the programme........ 30\nation location........................... 12\n13.9 Adding laundry...................... 31\n4.4 Removing the transit bolts...... 13\n13.10 Cancelling the pro-\n4.5 Connecting the appliance....... 14 gramme............................... 31'}]

# %% [markdown]
# # Pypdfium4ll

# %%
class text_chunker():
    # Take in file name
    def __init__(self, pdf):
        self.pdf_name = pdf
        self.newpath = "Washer_Images/Washer_Manuals/pymupdf4llm/" + self.pdf_name
        # make dir
        if not os.path.exists(self.newpath):
            os.makedirs(self.newpath)
        

    def extract_text_and_images(self):
        """Extracts images and saves them in 'self.newpath'
        """
        pymupdf4llm.to_markdown(doc=f"Washer_Manuals/{self.pdf_name}", write_images=True, image_path= self.newpath)
        # self.text = pathlib.Path("output.md").write_bytes(self.md_text.encode())
        print(self.text)

    def extract_page_cunks(self):
        # testing something with text and markdown. Does not work!
        self.document = pymupdf4llm.to_markdown(doc=f"Washer_Manuals/{self.pdf_name}", page_chunks=True)
        
        for index, page in enumerate(self.document):
            
            print(page["text"])
            print("Encoded text: ", pathlib.Path("output.md").write_bytes(page["text"].encode()))
            print(self.document[index])
            self.document[index]["text"] =  pathlib.Path("output.md").write_bytes(page["text"].encode())
        # self.text = pathlib.Path("output.md").write_bytes(self.md_text.encode())
        print(self.document[11]["text"])
        

    def process(self, pdf_text: str):
        
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size = 1512, #Adjust this as you see fit
            chunk_overlap  = 256, #This let's text have some form of overlap. Useful for keeping chunks contextual
            length_function = len
        )
    
        chunks = text_splitter.split_text(pdf_text)
        self.df = pd.DataFrame(chunks, columns=['chunks'])
        
        
        yield from self.df.itertuples(index=False, name=None)

# %%
cunker_object = text_chunker(pdf="k714wm14 service manual.pdf")
cunker_object.extract_page_cunks()
# Out:
# # �������������������������� ���������������
# ## � ������������ ���������������
#
#
# -----
#
#
# Encoded text:  226
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 1}, 'toc_items': [], 'tables': [], 'images': [{'number': 0, 'bbox': Rect(174.83399963378906, 331.0339660644531, 426.0059814453125, 657.5659790039062), 'transform': (251.1719970703125, 0.0, -0.0, 326.5320129394531, 174.83399963378906, 331.0339660644531), 'width': 697, 'height': 906, 'colorspace': 1, 'cs-name': 'Indexed(131,ICCBased(RGB,sRGB IEC61966-2.1))', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 23922, 'has-mask': False}], 'graphics': [], 'text': '# �������������������������� ���������������\n## � ������������ ���������������\n\n\n-----\n\n', 'words': []}
# ##### **�����������������**
#
#
# �����������������
#
# �������������� �������������������
#
# ��������� ��������������������������
#
# �������������������������
#
# ���������������������������������
#
# �������������������������������������
#
# �������������������� �����������������
#
# ����������������������
#
# �������� �������� ����������������
#
# �������������� ��������� ������������������
#
# ��������������� �������� �������������������������������
#
# ��������������� �������� ������������������
#
# ��������������� �������� ����������������
#
# ��������������� �������� ��������������
#
# �������������� �������� ������
#
# ��������������� �������� ������������������������
#
# ������������
#
# ���������������������������
#
# ������������������������������
#
# ������������������
#
# ��������������������������
#
# �������������������������
#
# �����������������������������
#
# �������������������������������������
#
# ���������������������������
#
# ���������������������
#
# ������������������������
#
# �������������������������
#
# �������������������
#
# �������������������
#
# �������������������
#
# ���������������������
#
# ����������������
#
# �������������������������
#
# �������������� ������������
#
# �������������� �������� �����������������������������������������������������������������������������������������������������
#
# ��������� ������������������
#
# ��������� ������������ ������������������������������������������������������������������������������������������������������
#
#
# ������������������� ���������������������������������������������������������������
#
# �������������� ������������������� �����������������������������������������
#
# ��������� �������������������������� ����������������������������
#
# ������������������������� ������������������������������
#
# ��������������������������������� ��������������������������������
#
# ������������������������������������� �������������������������������
#
# �������������������� ����������������� �������������������������
#
# ���������������������� �������������������������������
#
# �������� �������� ���������������� ������������������������������������������������������������������
#
# �������������� ��������� ������������������ ����������������������
#
# ��������������� �������� ������������������������������� �������������������
#
# ��������������� �������� ������������������ ������������������������
#
# ��������������� �������� ���������������� ��������������������������
#
# ��������������� �������� �������������� �������������������������
#
# �������������� �������� ������ ���������������������������
#
# ��������������� �������� ������������������������ ������������������������
#
# �������������� �����������������������������������
#
# ��������������������������� ��������������������������������
#
# ������������������������������ ������������������������������
#
# ������������������ ����������������������������������
#
# �������������������������� ������������������������������
#
# ������������������������� ��������������������������������
#
# ����������������������������� ����������������������������
#
# ������������������������������������� ��������������������������
#
# ����������������������������� ���������������������
#
# ��������������������� ������������������������������
#
# ������������������������ ������������������������������
#
# ������������������������� �����������������������������
#
# ������������������� �������������������������������
#
# ������������������� �������������������������������
#
# ������������������� �������������������������������
#
# ��������������������� ��������������������������������
#
# ���������������� ������������������������������������
#
# ������������������������� �����������������������������
#
# �������������� ������������ ��������������������������������
#
# �������������� �������� �����������������������������������������������������������������������������������������������������
#
# ��������� ������������������ ��������������������������������������������������������������������������������������������
#
# ��������� ������������ ������������������������������������������������������������������������������������������������������
#
#
# � ���������
#
# �
#
# �
#
# �
#
# �
#
# �
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
# ��
#
n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **������������������������������������������������**
#
# �����������������������������������������������������������������������������������������
#
# ������������������������������������������������������������������������������������������������
#
# �����������������������
# ###### � �����������������������������
#
#
# ���
#
# ���
#
#
# ���
#
#
# ����
#
#
# -----
#
#
# Encoded text:  943
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 7}, 'toc_items': [], 'tables': [], 'images': [{'number': 11, 'bbox': Rect(102.9540023803711, 523.154052734375, 279.5459899902344, 767.426025390625), 'transform': (176.5919952392578, 0.0, -0.0, 244.27200317382812, 102.9540023803711, 523.154052734375), 'width': 490, 'height': 678, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 23836, 'has-mask': False}, {'number': 7, 'bbox': Rect(105.41400146484375, 223.0339813232422, 281.22601318359375, 466.1659851074219), 'transform': (175.81199645996094, 0.0, -0.0, 243.1320037841797, 105.41400146484375, 223.0339813232422), 'width': 488, 'height': 675, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 24236, 'has-mask': False}, {'number': 9, 'bbox': Rect(362.27398681640625, 220.99400329589844, 537.9660034179688, 463.46600341796875), 'transform': (175.69200134277344, 0.0, -0.0, 242.4720001220703, 362.27398681640625, 220.99400329589844), 'width': 487, 'height': 673, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 24215, 'has-mask': False}], 'graphics': [], 'text': '##### **������������������������������������������������**\n\n�����������������������������������������������������������������������������������������\n\n������������������������������������������������������������������������������������������������\n\n�����������������������\n###### � �����������������������������\n\n\n���\n\n���\n\n\n���\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **��������������������������**
# ###### **������������� ���� ����������������**
# ##### ����������������������������� ������������������������������������������������ �������������������������������������������� �������������������������������������� ������������������������������������������������� ��������������������������������������������������� ��������������������� ��������������� ����������������������� ��������� �������������������� ���������������� ���������������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  1379
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 8}, 'toc_items': [], 'tables': [], 'images': [{'number': 6, 'bbox': Rect(97.91400146484375, 153.91400146484375, 465.4859924316406, 455.84600830078125), 'transform': (367.5719909667969, 0.0, -0.0, 301.9320068359375, 97.91400146484375, 153.91400146484375), 'width': 655, 'height': 538, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 37185, 'has-mask': False}], 'graphics': [], 'text': '##### **��������������������������**\n###### **������������� ���� ����������������**\n##### ����������������������������� ������������������������������������������������ �������������������������������������������� �������������������������������������� ������������������������������������������������� ��������������������������������������������������� ��������������������� ��������������� ����������������������� ��������� �������������������� ���������������� ���������������\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **��������������������������**
# ###### **������������� ���� ����������������**
#
#
# ���������������������������
#
# ������������������
#
# ��������
#
# ����������������������
#
# �����������
#
# ������������
#
# �����������
#
# �������������
# �� � ������������
#
# ���������
#
# ���������������������
#
#
# ����������������������������
# ���������������������������
#
# ������
#
# ���������
#
# ������������������
# �������������
# �� � ����
# �� � ������������������
# �������������
# ���������
#
# ��������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  1249
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 9}, 'toc_items': [], 'tables': [], 'images': [{'number': 4, 'bbox': Rect(90.59400177001953, 139.69400024414062, 475.32598876953125, 452.84600830078125), 'transform': (384.73199462890625, 0.0, -0.0, 313.1520080566406, 90.59400177001953, 139.69400024414062), 'width': 720, 'height': 586, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 63132, 'has-mask': False}], 'graphics': [], 'text': '##### **��������������������������**\n###### **������������� ���� ����������������**\n\n\n���������������������������\n\n������������������\n\n��������\n\n����������������������\n\n�����������\n\n������������\n\n�����������\n\n�������������\n�� � ������������\n\n���������\n\n���������������������\n\n\n����������������������������\n���������������������������\n\n������\n\n���������\n\n������������������\n�������������\n�� � ����\n�� � ������������������\n�������������\n���������\n\n��������\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **������������������������������������������������**
# ###### **������������� ���� ����������������**
# ##### ������������������������� ���� ����� ���� ���������������� ������������ ���� �������������������� ���� �������� ���� ����������������������� ������������������������ ���������������������������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  852
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 10}, 'toc_items': [], 'tables': [], 'images': [{'number': 7, 'bbox': Rect(197.093994140625, 230.2939910888672, 387.666015625, 411.32598876953125), 'transform': (190.57200622558594, 0.0, -0.0, 181.03199768066406, 197.093994140625, 230.2939910888672), 'width': 340, 'height': 323, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 15926, 'has-mask': False}, {'number': 8, 'bbox': Rect(221.63400268554688, 135.31398010253906, 363.1260070800781, 232.94598388671875), 'transform': (141.49200439453125, 0.0, -0.0, 97.63200378417969, 221.63400268554688, 135.31398010253906), 'width': 232, 'height': 160, 'colorspace': 1, 'cs-name': 'Indexed(245,ICCBased(RGB,sRGB IEC61966-2.1))', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 19893, 'has-mask': False}], 'graphics': [], 'text': '##### **������������������������������������������������**\n###### **������������� ���� ����������������**\n##### ������������������������� ���� ����� ���� ���������������� ������������ ���� �������������������� ���� �������� ���� ����������������������� ������������������������ ���������������������������\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **��������������������������**
# ###### **������������� ���� ����������������**
# ##### ������������� �������������� ��������������� ���������������� ��������������� ������������������������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  529
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 11}, 'toc_items': [], 'tables': [], 'images': [{'number': 4, 'bbox': Rect(176.87399291992188, 132.614013671875, 394.6259765625, 501.6860046386719), 'transform': (217.7519989013672, 0.0, -0.0, 369.0719909667969, 176.87399291992188, 132.614013671875), 'width': 308, 'height': 522, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 17639, 'has-mask': False}], 'graphics': [], 'text': '##### **��������������������������**\n###### **������������� ���� ����������������**\n##### ������������� �������������� ��������������� ���������������� ��������������� ������������������������\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **������������������������������������������������**
# ###### **������������� ���� ����������������**
#
# ����������������������
#
# �����������������
#
# �����������
#
# �����������������
#
# ������������������������
#
# �������������
#
# �����������������
# �����������������
#
# ������������������
#
# �����������������
# ��������������������������
# ���� � �����������
#
# �� ��� ����������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  1009
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 12}, 'toc_items': [], 'tables': [], 'images': [{'number': 5, 'bbox': Rect(164.81399536132812, 143.89398193359375, 432.7859802246094, 425.4259948730469), 'transform': (267.97198486328125, 0.0, -0.0, 281.5320129394531, 164.81399536132812, 143.89398193359375), 'width': 514, 'height': 540, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 404985, 'has-mask': False}], 'graphics': [], 'text': '##### **������������������������������������������������**\n###### **������������� ���� ����������������**\n\n����������������������\n\n�����������������\n\n�����������\n\n�����������������\n\n������������������������\n\n�������������\n\n�����������������\n�����������������\n\n������������������\n\n�����������������\n��������������������������\n���� � �����������\n\n�� ��� ����������\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **��������������������������**
# ###### **����������������������������������**
#
# ���
#
# ���
#
# ���
#
# �����������������������������������������������������������������������
# �����������������������������������������������������������
# ��������������������������������������������������������������������������������������
# ������������������������������������
# �����������������������������������������������������������������������������������
# �������������������������������������������������������������������������
# �����������������������������������������������������������������������
#
#
# ����
#
#
# -----
#
#
# Encoded text:  1705
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 13}, 'toc_items': [], 'tables': [], 'images': [{'number': 7, 'bbox': Rect(95.5739974975586, 141.9739990234375, 523.6859741210938, 256.82598876953125), 'transform': (428.11199951171875, 0.0, -0.0, 114.85199737548828, 95.5739974975586, 141.9739990234375), 'width': 1188, 'height': 318, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 30127, 'has-mask': False}, {'number': 9, 'bbox': Rect(95.8740005493164, 427.9339904785156, 524.7059936523438, 541.7659912109375), 'transform': (428.8320007324219, 0.0, -0.0, 113.83200073242188, 95.8740005493164, 427.9339904785156), 'width': 1190, 'height': 315, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 31736, 'has-mask': False}, {'number': 8, 'bbox': Rect(95.69400024414062, 288.67401123046875, 524.946044921875, 399.98602294921875), 'transform': (429.25201416015625, 0.0, -0.0, 111.31199645996094, 95.69400024414062, 288.67401123046875), 'width': 1192, 'height': 309, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 30463, 'has-mask': False}], 'graphics': [], 'text': '##### **��������������������������**\n###### **����������������������������������**\n\n���\n\n���\n\n���\n\n�����������������������������������������������������������������������\n�����������������������������������������������������������\n��������������������������������������������������������������������������������������\n������������������������������������\n�����������������������������������������������������������������������������������\n�������������������������������������������������������������������������\n�����������������������������������������������������������������������\n\n\n����\n\n\n-----\n\n', 'words': []}
# #####
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 59}, 'toc_items': [], 'tables': [], 'images': [], 'graphics': [], 'text': '##### **�����������������**\n\n��������������� ����������������������������������������������\n\n\n\n\n\n\n\n\n\n\n\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **�����������������**
#
# ������������������������������������������������
#
#
#
#
#
#
#
# ����
#
#
# -----
#
#
# Encoded text:  237
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 60}, 'toc_items': [], 'tables': [], 'images': [], 'graphics': [], 'text': '##### **�����������������**\n\n������������������������������������������������\n\n\n\n\n\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **�����������������**
#
# ��������������������������������������������
#
#
#
#
#
#
#
#
#
# ����
#
#
# -----
#
#
# Encoded text:  227
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 61}, 'toc_items': [], 'tables': [], 'images': [], 'graphics': [], 'text': '##### **�����������������**\n\n��������������������������������������������\n\n\n\n\n\n\n\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **�����������������**
#
# ��������������� �����������������������������������������������
#
#
#
#
#
#
#
# ����
#
#
# -----
#
#
# Encoded text:  280
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 62}, 'toc_items': [], 'tables': [], 'images': [], 'graphics': [], 'text': '##### **�����������������**\n\n��������������� �����������������������������������������������\n\n\n\n\n\n\n\n����\n\n\n-----\n\n', 'words': []}
# ##### **�����������������**
# ###### **�����������������**
#
# ���������������������������������
#
#
#
#
# |����|Col2|Col3|
# |---|---|---|
# |Number|Tools|Suitable kit|
# |1|Sleeve spanner|Heater（1）|
# |||Motor（1），counterweight （5）|
# |||Drum tub assembly|
# |||Strap screw|
# |2|Spanner|Adjust pulley screw leg and undo transport bolts|
# |3|Pliers and pinchers|Assembling or auxiliary function|
# |4|Other tools(screwdriver, pliers and so on)|Common service tools|
#
#
# ����
#
#
# -----
#
#
# Encoded text:  619
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 63}, 'toc_items': [], 'tables': [{'bbox': (75.30921936035156, 482.0226135253906, 523.9410400390625, 654.3567504882812), 'rows': 8, 'columns': 3}], 'images': [{'number': 10, 'bbox': Rect(120.23400115966797, 152.77398681640625, 441.84600830078125, 456.8059997558594), 'transform': (321.61199951171875, 0.0, -0.0, 304.0320129394531, 120.23400115966797, 152.77398681640625), 'width': 892, 'height': 844, 'colorspace': 3, 'cs-name': 'ICCBased(RGB,sRGB IEC61966-2.1)', 'xres': 96, 'yres': 96, 'bpc': 8, 'size': 45627, 'has-mask': False}], 'graphics': [], 'text': '##### **�����������������**\n###### **�����������������**\n\n���������������������������������\n\n\n\n\n|����|Col2|Col3|\n|---|---|---|\n|Number|Tools|Suitable kit|\n|1|Sleeve spanner|Heater（1）|\n|||Motor（1），counterweight （5）|\n|||Drum tub assembly|\n|||Strap screw|\n|2|Spanner|Adjust pulley screw leg and undo transport bolts|\n|3|Pliers and pinchers|Assembling or auxiliary function|\n|4|Other tools(screwdriver, pliers and so on)|Common service tools|\n\n\n����\n\n\n-----\n\n', 'words': []}
# ### ������������������������� ������
# ###### **���������������������������������������������**
#
# ��� ������������
#
#
#
#
#
#
#
#
#
# |Col1|Load(kg)|Col3|Col4|Col5|Col6|Default Temp.( C)|Default Time (Min)|Col9|Col10|Col11|
# |---|---|---|---|---|---|---|---|---|---|---|
# ||6.0|7.0|||Softener Case|6.0/7.0|6.0|7.0|1200|1400|
# |Cotton Intensive|6.0|7.0||||40|118|118|1000|1000|
# |60°|6.0|7.0||||60|201|198|1200|1400|
# |40°|6.0|7.0||||40|201|198|1200|1400|
# |20°|6.0|7.0||||20|81|81|1000|1000|
# |Quick 15'|1.5|2.0||||Cold|15|15|800|800|
# |Eco Wash|6.0|7.0||||30|69|69|800|800|
# |Rinse&Spin|6.0|7.0||||NA|34|34|1000|1000|
# |Baby Care|6.0|7.0||||60|107|107|1000|1000|
# |Sports|6.0|7.0||||40|86|86|800|800|
# ||3.0|3.5||||40|73|73|800|800|
# |Mixed|6.0|7.0||||40|78|78|1000|1000|
# |Delicate|6.0|7.0||||30|66|66|600|600|
# ||1.5|2.5||||40|66|66|400|400|
# |Drain Only|6.0|7.0||||NA|1|1|0|0|
# |Spin Only|6.0|7.0||||NA|14|14|1000|1000|
#
#
# ����
#
#
# -----
#
#
# Encoded text:  1103
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 64}, 'toc_items': [], 'tables': [{'bbox': (80.489501953125, 171.51953125, 529.68798828125, 559.1115112304688), 'rows': 17, 'columns': 11}], 'images': [], 'graphics': [], 'text': "### ������������������������� ������\n###### **���������������������������������������������**\n\n��� ������������\n\n\n\n\n\n\n\n\n\n|Col1|Load(kg)|Col3|Col4|Col5|Col6|Default Temp.( C)|Default Time (Min)|Col9|Col10|Col11|\n|---|---|---|---|---|---|---|---|---|---|---|\n||6.0|7.0|||Softener Case|6.0/7.0|6.0|7.0|1200|1400|\n|Cotton Intensive|6.0|7.0||||40|118|118|1000|1000|\n|60°|6.0|7.0||||60|201|198|1200|1400|\n|40°|6.0|7.0||||40|201|198|1200|1400|\n|20°|6.0|7.0||||20|81|81|1000|1000|\n|Quick 15'|1.5|2.0||||Cold|15|15|800|800|\n|Eco Wash|6.0|7.0||||30|69|69|800|800|\n|Rinse&Spin|6.0|7.0||||NA|34|34|1000|1000|\n|Baby Care|6.0|7.0||||60|107|107|1000|1000|\n|Sports|6.0|7.0||||40|86|86|800|800|\n||3.0|3.5||||40|73|73|800|800|\n|Mixed|6.0|7.0||||40|78|78|1000|1000|\n|Delicate|6.0|7.0||||30|66|66|600|600|\n||1.5|2.5||||40|66|66|400|400|\n|Drain Only|6.0|7.0||||NA|1|1|0|0|\n|Spin Only|6.0|7.0||||NA|14|14|1000|1000|\n\n\n����\n\n\n-----\n\n", 'words': []}
# ##### **�������������������������**
#
# ###### **����**
#
# ###### **��������������������������**
#
#
#
#
#
# |�������������������|Col2|Col3|
# |---|---|---|
# |Model Parameters|MFG60-ES1202|MFG70-ES1403|
# |Anti-electricity|Class I|Class I|
# |Waterproof rating|IPX4|IPX4|
# |Rated washing capacity|6.0kg|7.0kg|
# |Rated spinning capacity|6.0kg|7.0kg|
# |Rated voltage|220-240V/50Hz|220-240V/50Hz|
# |Rated input current|10A|10A|
# |Rated dehydration speed|1200rpm|1400 rpm|
# |Heating power|1800W|1800W|
# |Working pressure|0.05~1MPa|0.05~1MPa|
# |Rated consumption of water|45L /cycle|54.5L /cycle|
# |Rated consumption of power|0.89kWh /cycle|1.02kWh /cycle|
# |Wash performance|1.031|1.031|
# |Energy rating|A+|A+|
# |Net weight|50kg|56kg|
# |Figure dimension (mm) ( length×width×high)|595×470×850|595×495×850|
#
#
# ���
#
#
# -----
#
#
# Encoded text:  944
# {'metadata': {'format': 'PDF 1.5', 'title': '维修手册_SERVICE MANUAL-SICILY GLORY(6.0,7.0KG)', 'author': '张晓良', 'subject': '', 'keywords': '', 'creator': 'CorelDRAW X5', 'producer': 'Acrobat Distiller 9.0.0 (Windows)', 'creationDate': "D:20140618154138+08'00'", 'modDate': "D:20140618154138+08'00'", 'trapped': '', 'encryption': None, 'file_path': 'Washer_Manuals/k714wm14 service manual.pdf', 'page_count': 65, 'page': 65}, 'toc_items': [], 'tables': [{'bbox': (83.88400268554688, 143.7560272216797, 460.1239929199219, 644.2529907226562), 'rows': 16, 'columns': 3}], 'images': [], 'graphics': [], 'text': '##### **�������������������������**\n\n###### **����**\n\n###### **��������������������������**\n\n\n\n\n\n|�������������������|Col2|Col3|\n|---|---|---|\n|Model Parameters|MFG60-ES1202|MFG70-ES1403|\n|Anti-electricity|Class I|Class I|\n|Waterproof rating|IPX4|IPX4|\n|Rated washing capacity|6.0kg|7.0kg|\n|Rated spinning capacity|6.0kg|7.0kg|\n|Rated voltage|220-240V/50Hz|220-240V/50Hz|\n|Rated input current|10A|10A|\n|Rated dehydration speed|1200rpm|1400 rpm|\n|Heating power|1800W|1800W|\n|Working pressure|0.05~1MPa|0.05~1MPa|\n|Rated consumption of water|45L /cycle|54.5L /cycle|\n|Rated consumption of power|0.89kWh /cycle|1.02kWh /cycle|\n|Wash performance|1.031|1.031|\n|Energy rating|A+|A+|\n|Net weight|50kg|56kg|\n|Figure dimension (mm) ( length×width×high)|595×470×850|595×495×850|\n\n\n���\n\n\n-----\n\n', 'words': []}
# 1009

# %%
# cunker_object.extract_page_cunks()

cunker_object.document[2]["text"]
# Out:
# 10699

# %%
def render_pdf_to_images(pdf_path, zoom=2.0):
    doc = fitz.open(pdf_path)
    images = []
    for i, page in enumerate(doc):
        mat = fitz.Matrix(zoom, zoom)
        pix = page.get_pixmap(matrix=mat)
        img_data = Image.frombytes("RGB", [pix.width, pix.height], pix.samples)
        images.append({
            "page_number": i + 1,
            "image": img_data
        })
    return images


def detect_image_regions(page_image):
    image = np.array(page_image)
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    _, thresh = cv2.threshold(gray, 240, 255, cv2.THRESH_BINARY_INV)

    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    regions = []
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        if w > 50 and h > 50:  # Skip tiny blocks (Maybe reconsider)
            regions.append([x, y, x + w, y + h])
    return regions


def crop_regions_from_image(page_image, regions, output_dir, page_num):
    os.makedirs(output_dir, exist_ok=True)
    saved_images = []

    for i, coords in enumerate(regions):
        x1, y1, x2, y2 = map(int, coords)
        cropped = page_image.crop((x1, y1, x2, y2))
        save_path = os.path.join(output_dir, f"page_{page_num}_img_{i+1}.png")
        cropped.save(save_path)
        saved_images.append({
            "page": page_num,
            "image_path": save_path,
            "coords": (x1, y1, x2, y2)
        })
    return saved_images


# This is the main function to extract images from the PDF
def extract_images_from_pdf(pdf_path:str, output_dir: str, verbose:int =0):
    rendered_pages = render_pdf_to_images(pdf_path)
    all_extracted = []

    for page_idx,page in enumerate(rendered_pages):
        page_num = page["page_number"]
        image = page["image"]
        if verbose > 0:
            print(f"Processing page {page_num}...")

        regions = detect_image_regions(image)
        if verbose > 0:
            print(f"Found {len(regions)} image regions on page {page_num}")

        if not regions:
            if verbose > 0:
                print(f"No image regions found on page {page_num}")
            continue
        
        # Creates an image directory for each PDF file
        image_output_dir = os.path.join(output_dir, pdf_path.split("/")[-1].replace(".pdf", ""))
        os.makedirs(image_output_dir, exist_ok=True)

        extracted = crop_regions_from_image(
            image, regions, output_dir=image_output_dir, page_num=page_num
        )
        all_extracted.extend(extracted)
    return all_extracted

extract_images_from_pdf(file_path, output_dir="Washer_Images", verbose = 1)
# Out:
# Processing page 1...
# Found 1 image regions on page 1
# Processing page 2...
# Found 1 image regions on page 2
# Processing page 3...
# Found 0 image regions on page 3
# No image regions found on page 3
# Processing page 4...
# Found 1 image regions on page 4
# Processing page 5...
# Found 0 image regions on page 5
# No image regions found on page 5
# Processing page 6...
# Found 0 image regions on page 6
# No image regions found on page 6
# Processing page 7...
# Found 0 image regions on page 7
# No image regions found on page 7
# Processing page 8...
# Found 0 image regions on page 8
# No image regions found on page 8
# Processing page 9...
# Found 0 image regions on page 9
# No image regions found on page 9
# Processing page 10...
# Found 0 image regions on page 10
# No image regions found on page 10
# Processing page 11...
# Found 0 image regions on page 11
# No image regions found on page 11
# Processing page 12...
# Found 0 image regions on page 12
# No image regions found on page 12
# Processing page 13...
# Found 7 image regions on page 13
# Processing page 14...
# Found 6 image regions on page 14
# Processing page 15...
# Found 4 image regions on page 15
# Processing page 16...
# Found 3 image regions on page 16
# Processing page 17...
# Found 1 image regions on page 17
# Processing page 18...
# Found 6 image regions on page 18
# Processing page 19...
# Found 7 image regions on page 19
# Processing page 20...
# Found 1 image regions on page 20
# Processing page 21...
# Found 0 image regions on page 21
# No image regions found on page 21
# Processing page 22...
# Found 0 image regions on page 22
# No image regions found on page 22
# Processing page 23...
# Found 0 image regions on page 23
# No image regions found on page 23
# Processing page 24...
# Found 0 image regions on page 24
# No image regions found on page 24
# Processing page 25...
# Found 0 image regions on page 25
# No image regions found on page 25
# Processing page 26...
# Found 0 image regions on page 26
# No image regions found on page 26
# Processing page 27...
# Found 0 image regions on page 27
# No image regions found on page 27
# Processing page 28...
# Found 0 image regions on page 28
# No image regions found on page 28
# Processing page 29...
# Found 0 image regions on page 29
# No image regions found on page 29
# Processing page 30...
# Found 4 image regions on page 30
# Processing page 31...
# Found 1 image regions on page 31
# Processing page 32...
# Found 1 image regions on page 32
# Processing page 33...
# Found 3 image regions on page 33
# Processing page 34...
# Found 6 image regions on page 34
# Processing page 35...
# Found 5 image regions on page 35
# Processing page 36...
# Found 4 image regions on page 36
# Processing page 37...
# Found 0 image regions on page 37
# No image regions found on page 37
# Processing page 38...
# Found 0 image regions on page 38
# No image regions found on page 38
# Processing page 39...
# Found 0 image regions on page 39
# No image regions found on page 39
# Processing page 40...
# Found 0 image regions on page 40
# No image regions found on page 40
# Processing page 41...
# Found 0 image regions on page 41
# No image regions found on page 41
# Processing page 42...
# Found 0 image regions on page 42
# No image regions found on page 42
# Processing page 43...
# Found 0 image regions on page 43
# No image regions found on page 43
# Processing page 44...
# Found 0 image regions on page 44
# No image regions found on page 44
# Processing page 45...
# Found 0 image regions on page 45
# No image regions found on page 45
# Processing page 46...
# Found 2 image regions on page 46
# Processing page 47...
# Found 1 image regions on page 47
# Processing page 48...
# Found 0 image regions on page 48
# No image regions found on page 48
# Processing page 49...
# Found 0 image regions on page 49
# No image regions found on page 49
# Processing page 50...
# Found 0 image regions on page 50
# No image regions found on page 50
# Processing page 51...
# Found 0 image regions on page 51
# No image regions found on page 51
# Processing page 52...
# Found 1 image regions on page 52
# [{'page': 1,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_1_img_1.png',
#   'coords': (0, 0, 839, 1191)},
#  {'page': 2,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_2_img_1.png',
#   'coords': (656, 87, 778, 209)},
#  {'page': 4,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_4_img_1.png',
#   'coords': (56, 232, 142, 289)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_1.png',
#   'coords': (144, 853, 224, 969)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_2.png',
#   'coords': (62, 853, 142, 969)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_3.png',
#   'coords': (464, 686, 788, 920)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_4.png',
#   'coords': (62, 657, 224, 773)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_5.png',
#   'coords': (62, 503, 224, 619)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_6.png',
#   'coords': (464, 372, 788, 605)},
#  {'page': 13,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_13_img_7.png',
#   'coords': (62, 330, 224, 446)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_1.png',
#   'coords': (464, 857, 788, 1090)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_2.png',
#   'coords': (79, 679, 403, 912)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_3.png',
#   'coords': (464, 564, 788, 797)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_4.png',
#   'coords': (79, 407, 403, 640)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_5.png',
#   'coords': (79, 135, 403, 368)},
#  {'page': 14,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_14_img_6.png',
#   'coords': (464, 114, 788, 347)},
#  {'page': 15,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_15_img_1.png',
#   'coords': (62, 884, 224, 1000)},
#  {'page': 15,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_15_img_2.png',
#   'coords': (62, 690, 224, 806)},
#  {'page': 15,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_15_img_3.png',
#   'coords': (464, 665, 788, 898)},
#  {'page': 15,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_15_img_4.png',
#   'coords': (62, 538, 224, 655)},
#  {'page': 16,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_16_img_1.png',
#   'coords': (79, 512, 403, 745)},
#  {'page': 16,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_16_img_2.png',
#   'coords': (464, 502, 788, 735)},
#  {'page': 16,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_16_img_3.png',
#   'coords': (79, 156, 403, 389)},
#  {'page': 17,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_17_img_1.png',
#   'coords': (79, 135, 403, 368)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_1.png',
#   'coords': (451, 610, 724, 710)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_2.png',
#   'coords': (67, 460, 342, 698)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_3.png',
#   'coords': (118, 361, 395, 708)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_4.png',
#   'coords': (404, 300, 777, 697)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_5.png',
#   'coords': (131, 299, 346, 439)},
#  {'page': 18,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_18_img_6.png',
#   'coords': (531, 258, 726, 502)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_1.png',
#   'coords': (100, 690, 593, 817)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_2.png',
#   'coords': (598, 560, 781, 817)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_3.png',
#   'coords': (379, 524, 754, 854)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_4.png',
#   'coords': (56, 524, 335, 772)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_5.png',
#   'coords': (207, 207, 325, 299)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_6.png',
#   'coords': (137, 99, 323, 371)},
#  {'page': 19,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_19_img_7.png',
#   'coords': (60, 96, 254, 336)},
#  {'page': 20,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_20_img_1.png',
#   'coords': (57, 183, 788, 520)},
#  {'page': 30,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_30_img_1.png',
#   'coords': (464, 407, 788, 640)},
#  {'page': 30,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_30_img_2.png',
#   'coords': (79, 407, 403, 640)},
#  {'page': 30,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_30_img_3.png',
#   'coords': (79, 135, 403, 368)},
#  {'page': 30,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_30_img_4.png',
#   'coords': (464, 114, 788, 347)},
#  {'page': 31,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_31_img_1.png',
#   'coords': (464, 735, 788, 968)},
#  {'page': 32,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_32_img_1.png',
#   'coords': (479, 305, 735, 502)},
#  {'page': 33,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_33_img_1.png',
#   'coords': (464, 811, 788, 1044)},
#  {'page': 33,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_33_img_2.png',
#   'coords': (464, 497, 788, 730)},
#  {'page': 33,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_33_img_3.png',
#   'coords': (464, 224, 788, 458)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_1.png',
#   'coords': (464, 721, 788, 954)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_2.png',
#   'coords': (464, 428, 788, 661)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_3.png',
#   'coords': (79, 407, 403, 640)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_4.png',
#   'coords': (629, 135, 788, 368)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_5.png',
#   'coords': (464, 135, 624, 368)},
#  {'page': 34,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_34_img_6.png',
#   'coords': (79, 114, 403, 347)},
#  {'page': 35,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_35_img_1.png',
#   'coords': (79, 861, 403, 1094)},
#  {'page': 35,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_35_img_2.png',
#   'coords': (464, 725, 788, 958)},
#  {'page': 35,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_35_img_3.png',
#   'coords': (79, 567, 403, 801)},
#  {'page': 35,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_35_img_4.png',
#   'coords': (464, 348, 788, 581)},
#  {'page': 35,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_35_img_5.png',
#   'coords': (79, 295, 403, 528)},
#  {'page': 36,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_36_img_1.png',
#   'coords': (243, 811, 403, 1044)},
#  {'page': 36,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_36_img_2.png',
#   'coords': (79, 811, 238, 1044)},
#  {'page': 36,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_36_img_3.png',
#   'coords': (79, 476, 403, 709)},
#  {'page': 36,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_36_img_4.png',
#   'coords': (79, 182, 403, 416)},
#  {'page': 46,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_46_img_1.png',
#   'coords': (79, 346, 403, 579)},
#  {'page': 46,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_46_img_2.png',
#   'coords': (464, 265, 788, 498)},
#  {'page': 47,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_47_img_1.png',
#   'coords': (85, 739, 144, 799)},
#  {'page': 52,
#   'image_path': 'Washer_Images\\Washer_Manuals\\WGG254Z0GB\\page_52_img_1.png',
#   'coords': (0, 0, 839, 1191)}]
